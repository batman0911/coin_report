# %%
import pandas as pd
import http.client
import json

# %%
# df = pd.read_csv('../files/Bank_payment_schedule.csv')
df = pd.read_excel('../files/json_giao dich loi_20220517.xlsx')
df.head()
# Out:
#    id  package_order  shop_code        wallet_id  source  destination  \
# 0 NaN            NaN        NaN  943269989048704     NaN          NaN
# 1 NaN            NaN        NaN  949980935055232     NaN          NaN
# 2 NaN            NaN        NaN  946340371164416     NaN          NaN
# 3 NaN            NaN        NaN  948335745501440     NaN          NaN
# 4 NaN            NaN        NaN  943953037302016     NaN          NaN
#
#    payment_name   amount status  description  ...  payment_key  \
# 0           NaN    46500   paid          NaN  ...     withdraw
# 1           NaN   834000   paid          NaN  ...     withdraw
# 2           NaN    74300   paid          NaN  ...     withdraw
# 3           NaN  7471000   paid          NaN  ...     withdraw
# 4           NaN   660000   paid          NaN  ...     withdraw
#
#    package_order_status wallet_acc_trans_id   fee              paid_at  \
# 0                   NaN                 NaN  5500  2022-05-16T07:04:25
# ...

# %%
def curlFunc(body):
    conn = http.client.HTTPSConnection("ghtk-payment.ghtk.vn")
    headers = {
        'Authorization': 'Bearer eyJhbGciOiJFUzI1NiIsImtpZCI6IjAxRk0zWllBQUpBQ0JCRE5YREE5VzlLVk5XXzE2MzY1MTY3MDIiLCJ0eXAiOiJKV1QifQ.....uDtC5IhCofJXRN3gbcjPjpNTBraLeCP40np0p3pT146YXbikb3A2Vlm3lsvkjs5KV5cXEElF1zN75_b4mBtpxw',
        'Content-Type': 'application/json',
        'Cookie': 'JSESSIONID=44AB9DA60C62A808CE0B081A7B5A7330; JSESSIONID=71AB702229BDAC2095B888E8054921B5; JSESSIONID=55DA1647E73CF86B66585A0EFA9DA4B8; JSESSIONID=201D428A6F07E5BFC3EEE03C35ECE0E9; JSESSIONID=CEB316196C0A623333780E554F7B2CCD'
    }

    payload = json.dumps(body)
    conn.request("POST", "/api/v1/wallet/transaction", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))

# %%
df = pd.read_json('../files/sample_2.csv')
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                           body
# {"transId":"950560366666752" accTransId:"950560366666753" userId:"910730130386816" requestId:"CADNQCVP33" shopCode:"S2545234" transCode:"chuyen_tien" subTransCode:"bank_payment_schedule" amount:-830000 description:"Chuyển tiền đến ngân hàng BIDV" status:"SUCCESS" createdAt:"1652140802000" fee:5500 openBalance:830000  closeBalance:0}
# ...

# %%
import http.client
import json

def curlFunc(body):
    conn = http.client.HTTPSConnection("ghtk-payment.ghtk.vn")
    headers = {
        'Authorization': 'Bearer eyJhbGciOiJFUzI1NiIsImtpZCI6IjAxRk0zWllBQUpBQ0JCRE5YREE5VzlLVk5XXzE2MzY1MTY3MDIiLCJ0eXAiOiJKV1QifQ.....uDtC5IhCofJXRN3gbcjPjpNTBraLeCP40np0p3pT146YXbikb3A2Vlm3lsvkjs5KV5cXEElF1zN75_b4mBtpxw',
        'Content-Type': 'application/json',
        'Cookie': 'JSESSIONID=44AB9DA60C62A808CE0B081A7B5A7330; JSESSIONID=71AB702229BDAC2095B888E8054921B5; JSESSIONID=55DA1647E73CF86B66585A0EFA9DA4B8; JSESSIONID=201D428A6F07E5BFC3EEE03C35ECE0E9; JSESSIONID=CEB316196C0A623333780E554F7B2CCD'
    }

    payload = json.loads(body)
    print(payload)
    conn.request("POST", "/api/v1/wallet/transaction", json.dumps(payload), headers)
    res = conn.getresponse()
    data = res.read()
    print(data)


# df = pd.read_csv('../files/Bank_payment_schedule.csv')
df = pd.read_table('../files/sample.txt')
# df[['body']] = df[['body']].astype(str)
df = df.astype({'body':'string'})
# df = df.astype(str)
df.info()
df.head()

df['body'].apply(lambda x: curlFunc(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   body    408 non-null    string
# dtypes: string(1)
# memory usage: 3.3 KB
# {'transId': '950560366956928', 'accTransId': '950560366956929', 'userId': '949593114059392', 'requestId': 'DAVZYADP48', 'shopCode': 'S19724004', 'transCode': 'chuyen_tien', 'subTransCode': 'bank_payment_schedule', 'amount': -23500, 'description': 'Chuyển tiền đến ngân hàng TCB', 'status': 'SUCCESS', 'createdAt': '1652140802000', 'fee': 5500, 'openBalance': 23500, 'closeBalance': 0}
# b''
# ...

# %%
import pandas as pd
import http.client
import json

conn = http.client.HTTPSConnection("ghtk-payment.ghtk.vn")
def report(body_str):
    headers = {
      'Authorization': 'Bearer eyJhbGciOiJFUzI1NiIsImtpZCI6IjAxRk0zWllBQUpBQ0JCRE5YREE5VzlLVk5XXzE2MzY1MTY3MDIiLCJ0eXAiOiJKV1QifQ.....4uEw7leZLm30R8OCACrUoZiLH_NrQiyveoxqrogXN_SZU4l2bjYsStHYpNj0aa2uVUtT-7fd6gr65hmskk3Qeg',
      'Content-Type': 'application/json',
      'Cookie': 'JSESSIONID=44AB9DA60C62A808CE0B081A7B5A7330; JSESSIONID=71AB702229BDAC2095B888E8054921B5; JSESSIONID=55DA1647E73CF86B66585A0EFA9DA4B8; JSESSIONID=FFA8BBDE2255C372B38F0D949124BDE8; JSESSIONID=544489A0ED81C282297E8FFEB4A260C5'
    }

    payload = json.loads(body_str)
    print(payload)
    conn.request("POST", "/api/v1/shop/report/closing-session", json.dumps(payload), headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))

rp = pd.read_excel('../files/shop_report.xlsx')
rp = rp.astype({'shop_code': 'string', 'date': 'string', 'transaction_id': 'string', 'shop_name': 'string'})

rp['body'] = rp.apply(lambda row: '{"shopCode":"' + row.shop_code + '","shopName":"' + row.shop_name + '","date":"' + row.date + '","transactionId":' + row.transaction_id + '}', axis=1)

rp.head()

rp['body'].apply(lambda x: report(x))
# Out:
# {'shopCode': 'S19673097', 'shopName': 'Tuấn Anh Lê', 'date': '18/05/2022', 'transactionId': 12261024}
# {"success":true,"data":{"fromDate":1652695686000,"toDate":1652832002000,"url":"https://cache.giaohangtietkiem.vn/d/0e8a4b30862f40949d15d0e0ba42a2f2.xls"}}
# {'shopCode': 'S19716871', 'shopName': 'Hoàng', 'date': '18/05/2022', 'transactionId': 12261020}
# {"success":true,"data":{"fromDate":1651143537000,"toDate":1652832003000,"url":"https://cache.giaohangtietkiem.vn/d/05bb8329c6034f9097a41558245068e2.xls"}}
# {'shopCode': 'S19751927', 'shopName': 'đỗ khoa', 'date': '18/05/2022', 'transactionId': 12261094}
# {"success":true,"data":{"fromDate":1652745603000,"toDate":1652832003000,"url":"https://cache.giaohangtietkiem.vn/d/dbe63b195af2447aa510def18f9ac04e.xls"}}
# {'shopCode': 'S36207', 'shopName': 'ĐẶNG THU PHƯƠNG', 'date': '18/05/2022', 'transactionId': 12261127}
# ...
